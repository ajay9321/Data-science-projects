# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/Users/ajaychaudhary/Desktop/DATASETS FOLDER/loan_data.csv')

# %%
df.head(2)
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# 1                 0.08                         2.0           504
#
#   previous_loan_defaults_on_file  loan_status
# 0                             No            1
# 1                            Yes            0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %%
df.isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['person_education'].value_counts()
# Out:
# person_education
# Bachelor       13399
# Associate      12028
# High School    11972
# Master          6980
# Doctorate        621
# Name: count, dtype: int64

# %%
df['person_home_ownership'].value_counts()
# Out:
# person_home_ownership
# RENT        23443
# MORTGAGE    18489
# OWN          2951
# OTHER         117
# Name: count, dtype: int64

# %%
df['loan_intent'].value_counts()
# Out:
# loan_intent
# EDUCATION            9153
# MEDICAL              8548
# VENTURE              7819
# PERSONAL             7552
# DEBTCONSOLIDATION    7145
# HOMEIMPROVEMENT      4783
# Name: count, dtype: int64

# %%
df['previous_loan_defaults_on_file'].value_counts()
# Out:
# previous_loan_defaults_on_file
# Yes    22858
# No     22142
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %% [markdown]
# # Data visualisation

# %%
# List of categorical and numerical columns
categorical_columns = ['person_gender', 'person_education', 'person_home_ownership', 
                       'loan_intent', 'previous_loan_defaults_on_file']
numerical_columns = ['person_age', 'person_income', 'person_emp_exp', 'loan_amnt', 
                     'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length', 'credit_score']

# Univariate Analysis for Categorical Columns
for col in categorical_columns:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette='viridis')
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.show()

# Univariate Analysis for Numerical Columns
for col in numerical_columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], kde=True, bins=30, color='blue')
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# Summary Statistics for Numerical Columns
numerical_summary = df[numerical_columns].describe()
print("Summary Statistics for Numerical Columns:")
print(numerical_summary)

# Value Counts for Categorical Columns
for col in categorical_columns:
    print(f"\nValue Counts for {col}:")
    print(df[col].value_counts())
# Out:
# /var/folders/03/24l9l0qj75bd3r5zk_j82v6h0000gn/T/ipykernel_6188/2562350331.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette='viridis')
# /var/folders/03/24l9l0qj75bd3r5zk_j82v6h0000gn/T/ipykernel_6188/2562350331.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette='viridis')
# /var/folders/03/24l9l0qj75bd3r5zk_j82v6h0000gn/T/ipykernel_6188/2562350331.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# # Bivaraiate analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatterplot for numeric variables
sns.scatterplot(data=df, x='person_income', y='loan_amnt')
plt.title('Relationship Between Income and Loan Amount')
plt.show()

# %%
# Cross-tabulation
crosstab = pd.crosstab(df['person_home_ownership'], df['loan_status'])
print(crosstab)

# Grouped Bar Plot
crosstab.plot(kind='bar', figsize=(8, 6), stacked=True)
plt.title('Loan Status by Home Ownership')
plt.xlabel('Home Ownership')
plt.ylabel('Frequency')
plt.legend(title='Loan Status')
plt.show()
# Out:
# loan_status                0     1
# person_home_ownership
# MORTGAGE               16345  2144
# OTHER                     78    39
# OWN                     2729   222
# RENT                   15848  7595

# %%
# Boxplot
sns.boxplot(data=df, x='loan_intent', y='loan_amnt')
plt.title('Loan Amount by Loan Intent')
plt.xticks(rotation=45)
plt.show()

# Violin Plot
sns.violinplot(data=df, x='loan_intent', y='loan_amnt', inner="quartile")
plt.title('Loan Amount Distribution by Loan Intent')
plt.xticks(rotation=45)
plt.show()

# %%
# Mean loan_status by gender
gender_loan_status = df.groupby('person_gender')['loan_status'].mean()
print(gender_loan_status)

# Bar Plot
gender_loan_status.plot(kind='bar', color='skyblue')
plt.title('Mean Loan Status by Gender')
plt.xlabel('Gender')
plt.ylabel('Mean Loan Status')
plt.show()
# Out:
# person_gender
# female    0.222481
# male      0.222012
# Name: loan_status, dtype: float64

# %% [markdown]
# # mutivariate analysis

# %%
sns.pairplot(df, vars=['person_income', 'loan_amnt', 'loan_int_rate', 'credit_score'], hue='loan_status', diag_kind='kde')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='loan_intent', hue='person_home_ownership', data=df)
plt.title('Loan Intent vs. Home Ownership')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='cb_person_cred_hist_length', y='credit_score', hue='loan_status', data=df)
plt.title('Credit History Length vs. Credit Score')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='loan_percent_income', y='credit_score', hue='loan_status', data=df)
plt.title('Loan Percent Income vs. Credit Score')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='loan_amnt', y='loan_int_rate', hue='person_education', data=df)
plt.title('Loan Amount vs. Interest Rate by Education Level')
plt.show()

# %%
from scipy.stats import f_oneway

anova_result = f_oneway(
    df[df['loan_intent'] == 'Car']['loan_amnt'],
    df[df['loan_intent'] == 'Home']['loan_amnt'],
    df[df['loan_intent'] == 'Education']['loan_amnt']
)

print(f"ANOVA p-value: {anova_result.pvalue}")
# Out:
# ANOVA p-value: nan
# /var/folders/03/24l9l0qj75bd3r5zk_j82v6h0000gn/T/ipykernel_6188/3709084884.py:3: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   anova_result = f_oneway(

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(df['person_gender'], df['loan_status'])
chi2, p, dof, expected = chi2_contingency(contingency_table)

print(f"Chi-Square p-value: {p}")
# Out:
# Chi-Square p-value: 0.9142540404277906

# %% [markdown]
# # Handle outliers

# %%
plt.figure(figsize=(8,3))
plt.boxplot(df['credit_score'], vert=False)
plt.title('Box Plot of Values')
plt.xlabel('credit_score')
plt.show()

# %%
# Columns having outliers:-
# person_age
# person_income
# person_emp_exp
# loan_amnt
# loan_percent_income
# credit_score

# %% [markdown]
# ### Syntax for handle outliers by IQR method on multiple columns

# %%
# Define columns to apply the IQR method
columns_to_check = ['person_income', 'loan_amnt', 'person_age','loan_percent_income','credit_score']

# Function to remove outliers using IQR
def remove_outliers_iqr(df, columns):
    for col in columns:
        Q1 = df[col].quantile(0.25)  # First quartile (25th percentile)
        Q3 = df[col].quantile(0.75)  # Third quartile (75th percentile)
        IQR = Q3 - Q1  # Interquartile range
        lower_bound = Q1 - 1.5 * IQR  # Lower bound
        upper_bound = Q3 + 1.5 * IQR  # Upper bound
        
        # Filter out rows with outliers
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df

# Apply the function
cleaned_df = remove_outliers_iqr(df, columns_to_check)

print("Original DataFrame:")
print(df)
print("\nCleaned DataFrame:")
print(cleaned_df)
# Out:
# Original DataFrame:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
cleaned_df
# Out:
#        person_age person_gender person_education  person_income  \
# 1            21.0        female      High School        12282.0
# 5            21.0        female      High School        12951.0
# 9            21.0        female      High School        12739.0
# 19           24.0        female           Master        14283.0
# 23           24.0        female         Bachelor        13866.0
# ...           ...           ...              ...            ...
# 44993        27.0        female      High School        35512.0
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 1                   0                   OWN     1000.0          EDUCATION
# ...

# %%
plt.figure(figsize=(8,3))
plt.boxplot(cleaned_df['person_age'], vert=False)
plt.title('Box Plot of Values')
plt.xlabel('person_age')
plt.show()

# %% [markdown]
# # Encoding

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37632 entries, 1 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      37632 non-null  float64
#  1   person_gender                   37632 non-null  object
#  2   person_education                37632 non-null  object
#  3   person_income                   37632 non-null  float64
#  4   person_emp_exp                  37632 non-null  int64
#  5   person_home_ownership           37632 non-null  object
#  6   loan_amnt                       37632 non-null  float64
#  7   loan_intent                     37632 non-null  object
#  8   loan_int_rate                   37632 non-null  float64
#  9   loan_percent_income             37632 non-null  float64
#  10  cb_person_cred_hist_length      37632 non-null  float64
#  11  credit_score                    37632 non-null  int64
# ...

# %%
# person_gender
# person_education
# person_home_ownership
# loan_intent
# previous_loan_defaults_on_file

# %%
# Label encoding

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# List of columns to encode
columns_to_encode = [
    'person_gender',
    'person_education',
    'person_home_ownership',
    'loan_intent',
    'previous_loan_defaults_on_file'
]

# Apply label encoding to each specified column
for column in columns_to_encode:
    cleaned_df[column] = label_encoder.fit_transform(cleaned_df[column])

# Display the encoded DataFrame
print(cleaned_df)
# Out:
#        person_age  person_gender  person_education  person_income  \
# 1            21.0              0                 3        12282.0
# 5            21.0              0                 3        12951.0
# 9            21.0              0                 3        12739.0
# 19           24.0              0                 4        14283.0
# 23           24.0              0                 1        13866.0
# ...           ...            ...               ...            ...
# 44993        27.0              0                 3        35512.0
# 44995        27.0              1                 0        47971.0
# 44996        37.0              0                 0        65800.0
# 44997        33.0              1                 0        56942.0
# 44999        24.0              1                 3        51609.0
#
#        person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 1                   0                      2     1000.0            1
# ...

# %%
cleaned_df.head(3)
# Out:
#    person_age  person_gender  person_education  person_income  person_emp_exp  \
# 1        21.0              0                 3        12282.0               0
# 5        21.0              0                 3        12951.0               0
# 9        21.0              0                 3        12739.0               0
#
#    person_home_ownership  loan_amnt  loan_intent  loan_int_rate  \
# 1                      2     1000.0            1          11.14
# 5                      2     2500.0            5           7.14
# 9                      2     1600.0            5          14.74
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 1                 0.08                         2.0           504
# 5                 0.19                         2.0           532
# 9                 0.13                         3.0           640
#
#    previous_loan_defaults_on_file  loan_status
# 1                               1            0
# ...

# %%
# check imbalanced data 
cleaned_df['loan_status'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, figsize=(6, 6))
plt.title('Class Distribution')
plt.ylabel('')
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# import libraries for the model 
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# import libraries for evaluation
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X = cleaned_df.drop('loan_status', axis=1)  # Exited คือนิยามเป้าหมาย
y = cleaned_df['loan_status']  # เป้าหมายของเรา (ถูกหรือไม่ถูก)

# Split Testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
 
print(f"Train set: {X_train.shape}, Test set: {X_test.shape}")
# Out:
# Train set: (26342, 13), Test set: (11290, 13)

# %%
# Import the RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

# Create the Random Forest model
model_RF = RandomForestClassifier(random_state=42)

# Train the model using the Train set
model_RF.fit(X_train, y_train)

# Predict the results on the Test set
y_pred_RF = model_RF.predict(X_test)

# Evaluate the predictions
print("Random Forest")
print(" ")
print("Accuracy:", accuracy_score(y_test, y_pred_RF))
accuracy_rf = accuracy_score(y_test, y_pred_RF)

# Calculate Precision, Recall, and F1-Score
precision_RF = precision_score(y_test, y_pred_RF)
recall_RF = recall_score(y_test, y_pred_RF)
f1_RF = f1_score(y_test, y_pred_RF)

# Display the results
print(f"Precision_RF: {precision_RF}")
print(f"Recall_RF: {recall_RF}")
print(f"F1 Score_RF: {f1_RF}")

# Calculate the Confusion Matrix
cm_RF = confusion_matrix(y_test, y_pred_RF)
print("Confusion Matrix_RF:")
print(cm_RF)
# Out:
# Random Forest
#
# Accuracy: 0.9230292294065545
# Precision_RF: 0.8653146125845034
# Recall_RF: 0.731750219876869
# F1 Score_RF: 0.7929473433404813
# Confusion Matrix_RF:
# [[8757  259]
#  [ 610 1664]]

# %%
# Import the DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier

# Create the Decision Tree model
model_DT = DecisionTreeClassifier(random_state=42)

# Train the model using the Train set
model_DT.fit(X_train, y_train)

# Predict the results on the Test set
y_pred_DT = model_DT.predict(X_test)

# Evaluate the predictions
print("Decision Tree")
print(" ")
print("Accuracy:", accuracy_score(y_test, y_pred_DT))
accuracy_dt = accuracy_score(y_test, y_pred_DT)

# Calculate Precision, Recall, and F1-Score
precision_DT = precision_score(y_test, y_pred_DT)
recall_DT = recall_score(y_test, y_pred_DT)
f1_DT = f1_score(y_test, y_pred_DT)

# Display the results
print(f"Precision_DT: {precision_DT}")
print(f"Recall_DT: {recall_DT}")
print(f"F1 Score_DT: {f1_DT}")

# Calculate the Confusion Matrix
cm_DT = confusion_matrix(y_test, y_pred_DT)
print("Confusion Matrix_DT:")
print(cm_DT)
# Out:
# Decision Tree
#
# Accuracy: 0.8906997342781222
# Precision_DT: 0.7272727272727273
# Recall_DT: 0.731750219876869
# F1 Score_DT: 0.7295046032441912
# Confusion Matrix_DT:
# [[8392  624]
#  [ 610 1664]]

# %%
# Import the GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier

# Create the Gradient Boosting model
model_GB = GradientBoostingClassifier(random_state=42)

# Train the model using the Train set
model_GB.fit(X_train, y_train)

# Predict the results on the Test set
y_pred_GB = model_GB.predict(X_test)

# Evaluate the predictions
print("Gradient Boosting")
print(" ")
print("Accuracy:", accuracy_score(y_test, y_pred_GB))
accuracy_gb = accuracy_score(y_test, y_pred_GB)

# Calculate Precision, Recall, and F1-Score
precision_GB = precision_score(y_test, y_pred_GB)
recall_GB = recall_score(y_test, y_pred_GB)
f1_GB = f1_score(y_test, y_pred_GB)

# Display the results
print(f"Precision_GB: {precision_GB}")
print(f"Recall_GB: {recall_GB}")
print(f"F1 Score_GB: {f1_GB}")

# Calculate the Confusion Matrix
cm_GB = confusion_matrix(y_test, y_pred_GB)
print("Confusion Matrix_GB:")
print(cm_GB)
# Out:
# Gradient Boosting
#
# Accuracy: 0.9180690876882197
# Precision_GB: 0.8503896103896104
# Recall_GB: 0.7198768689533861
# F1 Score_GB: 0.7797094546320552
# Confusion Matrix_GB:
# [[8728  288]
#  [ 637 1637]]

# %%
# Import the SVC (Support Vector Classifier)
from sklearn.svm import SVC

# Create the SVM model
model_SVM = SVC(random_state=42)

# Train the model using the Train set
model_SVM.fit(X_train, y_train)

# Predict the results on the Test set
y_pred_SVM = model_SVM.predict(X_test)

# Evaluate the predictions
print("Support Vector Machine")
print(" ")
print("Accuracy:", accuracy_score(y_test, y_pred_SVM))
accuracy_svm = accuracy_score(y_test, y_pred_SVM)

# Calculate Precision, Recall, and F1-Score
precision_SVM = precision_score(y_test, y_pred_SVM)
recall_SVM = recall_score(y_test, y_pred_SVM)
f1_SVM = f1_score(y_test, y_pred_SVM)

# Display the results
print(f"Precision_SVM: {precision_SVM}")
print(f"Recall_SVM: {recall_SVM}")
print(f"F1 Score_SVM: {f1_SVM}")

# Calculate the Confusion Matrix
cm_SVM = confusion_matrix(y_test, y_pred_SVM)
print("Confusion Matrix_SVM:")
print(cm_SVM)
# Out:
# Support Vector Machine
#
# Accuracy: 0.8115146147032772
# Precision_SVM: 0.8230088495575221
# Recall_SVM: 0.08179419525065963
# F1 Score_SVM: 0.1488
# Confusion Matrix_SVM:
# [[8976   40]
#  [2088  186]]

# %%
# Import the KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier

# Create the KNN model
model_KNN = KNeighborsClassifier(n_neighbors=5)  # You can adjust n_neighbors

# Train the model using the Train set
model_KNN.fit(X_train, y_train)

# Predict the results on the Test set
y_pred_KNN = model_KNN.predict(X_test)

# Evaluate the predictions
print("K-Nearest Neighbors")
print(" ")
print("Accuracy:", accuracy_score(y_test, y_pred_KNN))
accuracy_knn = accuracy_score(y_test, y_pred_KNN)

# Calculate Precision, Recall, and F1-Score
precision_KNN = precision_score(y_test, y_pred_KNN)
recall_KNN = recall_score(y_test, y_pred_KNN)
f1_KNN = f1_score(y_test, y_pred_KNN)

# Display the results
print(f"Precision_KNN: {precision_KNN}")
print(f"Recall_KNN: {recall_KNN}")
print(f"F1 Score_KNN: {f1_KNN}")

# Calculate the Confusion Matrix
cm_KNN = confusion_matrix(y_test, y_pred_KNN)
print("Confusion Matrix_KNN:")
print(cm_KNN)
# Out:
# K-Nearest Neighbors
#
# Accuracy: 0.8349867139061116
# Precision_KNN: 0.6231276213301378
# Recall_KNN: 0.4573438874230431
# F1 Score_KNN: 0.5275171189449658
# Confusion Matrix_KNN:
# [[8387  629]
#  [1234 1040]]

# %%
# สร้างโมเดล Logistic Regression
model_Logis = LogisticRegression()

# ฝึกโมเดลด้วยข้อมูลใน Train set
model_Logis.fit(X_train, y_train)

# ทำนายผลลัพธ์จากข้อมูลใน Test set
y_pred_Logis = model_Logis.predict(X_test)

# ประเมินผลการทำนาย
print("LogisticRegression")
print(" ")
print("Accuracy:", accuracy_score(y_test, y_pred_Logis))
accuracy_logistic = accuracy_score(y_test, y_pred_Logis)

# คำนวณ Precision, Recall, F1-Score
precision_Logis = precision_score(y_test, y_pred_Logis)
recall_Logis = recall_score(y_test, y_pred_Logis)
f1_Logis = f1_score(y_test, y_pred_Logis)

# แสดงผลลัพธ์
print(f"Precision_Logis: {precision_Logis}")
print(f"Recall_Logis: {recall_Logis}")
print(f"F1 Score_Logis: {f1_Logis}")

# คำนวณ Confusion Matrix
cm_Logis = confusion_matrix(y_test, y_pred_Logis)
print("Confusion Matrix_Logis:")
print(cm_Logis)
# Out:
# LogisticRegression
#
# Accuracy: 0.8493356953055802
# Precision_Logis: 0.6805293005671077
# Recall_Logis: 0.47493403693931396
# F1 Score_Logis: 0.5594405594405595
# Confusion Matrix_Logis:
# [[8509  507]
#  [1194 1080]]
# /Applications/anaconda3/envs/notebook-6.5.7_2/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Create a dictionary to store the accuracy of each model
model_names = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'Gradient Boosting', 'SVM', 'KNN']
accuracies = [accuracy_logistic, accuracy_dt, accuracy_rf, accuracy_gb, accuracy_svm, accuracy_knn]

# Create a DataFrame for visualization
import pandas as pd

results_df = pd.DataFrame({
    'Model': model_names,
    'Accuracy': accuracies
})

# Display the DataFrame
print(results_df)

# Plotting the results (optional)
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x='Accuracy', y='Model', data=results_df, palette='viridis')
plt.title('Model Accuracy Comparison')
plt.show()
# Out:
#                  Model  Accuracy
# 0  Logistic Regression  0.849336
# 1        Decision Tree  0.890700
# 2        Random Forest  0.923029
# 3    Gradient Boosting  0.918069
# 4                  SVM  0.811515
# 5                  KNN  0.834987
# /var/folders/03/24l9l0qj75bd3r5zk_j82v6h0000gn/T/ipykernel_6188/2098339405.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Accuracy', y='Model', data=results_df, palette='viridis')
