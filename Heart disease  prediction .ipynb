# %%
# import libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data
df=pd.read_csv('/Users/ajaychaudhary/Downloads/heart.csv')

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df.sample(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 252   62    0   0       138   294    1        1      106      0      1.9
# 149   42    1   2       130   180    0        1      150      0      0.0
# 51    66    1   0       120   302    0        0      151      0      0.4
# 128   52    0   2       136   196    0        0      169      0      0.1
# 297   59    1   0       164   176    1        0       90      0      1.0
#
#      slope  ca  thal  target
# 252      1   3     2       0
# 149      2   0     2       1
# 51       1   0     2       1
# 128      1   0     2       1
# 297      1   2     1       0

# %%
# lets check the null values in the dataset
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.shape
# Out:
# (303, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# lets check the statistics of the dataset
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# Statstical Details Describe provides us with statistical information in the numerical format. we can infer that in the AGE column the minimum age is 29yrs and maximium is 77yrs mean of age is 54yrs. The quartiles details are given in form of 25%, 50% and 75%. The data is divided into 3 quartiles or 4 equal parts. so 25% values lie in each group. standard deviation and mean are statistical measures which give us an idea of the central tendency of the data set. However , mean is effected by outliers and hence we need more information to make accurate decisions.

# %% [markdown]
# # Finding the correlation among the attributes

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df.corr(), annot=True, cmap='terrain')
# Out:
# <Axes: >

# %%
df.hist(figsize=(12,12), layout=(5,3));

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
# box and whiskers plot
df.plot(kind='box', subplots=True, layout=(5,3), figsize=(12,12))
plt.show()

# %%
sns.catplot(data=df, x='sex', y='age',  hue='target', palette='husl')

# %%
sns.barplot(data=df, x='sex', y='chol', hue='target', palette='spring')
# Out:
# <Axes: xlabel='sex', ylabel='chol'>

# %%
df['sex'].value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
sns.countplot(x='sex', data=df, palette='husl', hue='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ###  In this dataset 96 are females and 207 males

# %%
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %% [markdown]
# ### 165 cases of heart diseases,and 138 cases of no heart disease

# %%
sns.countplot(x='target', data=df, palette='husl', hue='target')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
df['thal'].value_counts()
# Out:
# 2    166
# 3    117
# 1     18
# 0      2
# Name: thal, dtype: int64

# %% [markdown]
# #results of thallium stress test measuring blood flow to the heart,
#
# with possible values normal, fixed_defect, reversible_defect
#
#
# Thalium stress test result:
#
# 0: Normal
#
# 1: Fixed defect
#
# 2: Reversible defect
#
# 3: Not described

# %%
sns.countplot(x='sex', data=df, palette='husl', hue='target')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ## Here 0 means females and 1 denotes male. we observe that female having heart disease are comparatively less when compared to males . females have low heart diseases as compared to males in the given dataset.

# %%
sns.countplot(x='target',palette='BuGn', data=df)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %% [markdown]
# ## we observe that , the count for not having heart disease and having heart disease are almost balanced not having frequency count is 138 and those having heart disease the count is 165.

# %%
sns.countplot(x='ca',hue='target',data=df)
# Out:
# <Axes: xlabel='ca', ylabel='count'>

# %% [markdown]
# ### ca : number of major vessels (0-4) colored by flourosopy

# %%
df['ca'].value_counts()
# Out:
# 0    175
# 1     65
# 2     38
# 3     20
# 4      5
# Name: ca, dtype: int64

# %% [markdown]
# ### ca number of major vessels (0-4) colored by flourosopy ca has a negative corelation with the target i.e when ca will increase we witness a drop in heart diseases and vice versa.

# %%
sns.countplot(x='thal',data=df, hue='target', palette='BuPu' )
# Out:
# <Axes: xlabel='thal', ylabel='count'>

# %%
sns.countplot(x='thal', hue='sex',data=df, palette='terrain')
# Out:
# <Axes: xlabel='thal', ylabel='count'>

# %%
df['cp'].value_counts()  # chest pain type
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
sns.countplot(x='cp' ,hue='target', data=df, palette='rocket')
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %% [markdown]
# shows chest pain with respect to heart disease/ target
#
# Chest pain type:
# 0: Typical angina
# 1: Atypical angina
# 2: Non-anginal pain
# 3: Asymptomatic

# %%
sns.countplot(x='cp', hue='sex',data=df, palette='BrBG')
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %% [markdown]
# this shows chest pain count experienced by male and female

# %%
sns.boxplot(x='sex', y='chol', hue='target', palette='seismic', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='chol'>

# %% [markdown]
# we observe the outliers with the help of boxplot. outliers are values that are very small or large in the given data set.

# %%
sns.barplot(x='sex', y='cp', hue='target',data=df, palette='cividis')
# Out:
# <Axes: xlabel='sex', ylabel='cp'>

# %%
sns.barplot(x='sex', y='thal', data=df, hue='target', palette='nipy_spectral')
# Out:
# <Axes: xlabel='sex', ylabel='thal'>

# %%
sns.barplot(x='target', y='ca', hue='sex', data=df, palette='mako')
# Out:
# <Axes: xlabel='target', ylabel='ca'>

# %%
sns.barplot(x='sex', y='oldpeak', hue='target', palette='rainbow', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='oldpeak'>

# %% [markdown]
# ST depression induced by exercise relative to rest, a measure of abnormality in electrocardiograms

# %% [markdown]
# # fbs(fasting blood sugar > 120 mg/dl) (1 = true; 0 = false) and chest pain relation

# %%
df['fbs'].value_counts()
# Out:
# 0    258
# 1     45
# Name: fbs, dtype: int64

# %%
sns.barplot(x='fbs', y='chol', hue='target', data=df,palette='plasma' )
# Out:
# <Axes: xlabel='fbs', ylabel='chol'>

# %%
sns.barplot(x='sex',y='target', hue='fbs',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='target'>

# %% [markdown]
# # Cross tables

# %%
gen = pd.crosstab(df['sex'], df['target'])
print(gen)
# Out:
# target    0   1
# sex
# 0        24  72
# 1       114  93

# %%
gen.plot(kind='bar', stacked=True, color=['green','yellow'], grid=False)
# Out:
# <Axes: xlabel='sex'>

# %%
	
temp=pd.crosstab(index=df['sex'],
            columns=[df['thal']], 
            margins=True)
temp
# Out:
# thal  0   1    2    3  All
# sex
# 0     1   1   79   15   96
# 1     1  17   87  102  207
# All   2  18  166  117  303

# %%
temp.plot(kind="bar",stacked=True)
plt.show()

# %%
temp=pd.crosstab(index=df['target'],
            columns=[df['thal']], 
            margins=True)
temp
# Out:
# thal    0   1    2    3  All
# target
# 0       1  12   36   89  138
# 1       1   6  130   28  165
# All     2  18  166  117  303

# %%
temp.plot(kind='bar', stacked=True)
plt.show()

# %%
chest_pain = pd.crosstab(df['cp'], df['target'])
chest_pain
# Out:
# target    0   1
# cp
# 0       104  39
# 1         9  41
# 2        18  69
# 3         7  16

# %%
chest_pain.plot(kind='bar', stacked=True, color=['purple','blue'], grid=False)
# Out:
# <Axes: xlabel='cp'>

# %% [markdown]
# # Preparing the data for model building

# %% [markdown]
# ## Scaling the data

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
StandardScaler = StandardScaler()  
columns_to_scale = ['age','trestbps','chol','thalach','oldpeak']
df[columns_to_scale] = StandardScaler.fit_transform(df[columns_to_scale])

# %%
df.head()
# Out:
#         age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0  0.952197    1   3  0.763956 -0.256334    1        0  0.015443      0
# 1 -1.915313    1   2 -0.092738  0.072199    0        1  1.633471      0
# 2 -1.474158    0   1 -0.092738 -0.816773    0        0  0.977514      0
# 3  0.180175    1   1 -0.663867 -0.198357    0        1  1.239897      0
# 4  0.290464    0   0 -0.663867  2.082050    0        1  0.583939      1
#
#     oldpeak  slope  ca  thal  target
# 0  1.087338      0   0     1       1
# 1  2.122573      0   0     2       1
# 2  0.310912      2   0     2       1
# 3 -0.206705      2   0     2       1
# 4 -0.379244      2   0     2       1

# %%
X= df.drop(['target'], axis=1)
y= df['target']

# %%
X_train, X_test,y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=40)

# %% [markdown]
# # Check the sample Size

# %%
print('X_train-', X_train.size)
print('X_test-',X_test.size)
print('y_train-', y_train.size)
print('y_test-', y_test.size)
# Out:
# X_train- 2756
# X_test- 1183
# y_train- 212
# y_test- 91

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

model1=lr.fit(X_train,y_train)
prediction1=model1.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,prediction1)
cm
# Out:
# array([[36,  4],
#        [ 3, 48]])

# %%
sns.heatmap(cm, annot=True,cmap='BuPu')
# Out:
# <Axes: >

# %%
TP=cm[0][0]
TN=cm[1][1]
FN=cm[1][0]
FP=cm[0][1]
print('Testing Accuracy:',(TP+TN)/(TP+TN+FN+FP))
# Out:
# Testing Accuracy: 0.9230769230769231

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,prediction1)
# Out:
# 0.9230769230769231

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91        40
#            1       0.92      0.94      0.93        51
#
#     accuracy                           0.92        91
#    macro avg       0.92      0.92      0.92        91
# weighted avg       0.92      0.92      0.92        91

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier()
model2=dtc.fit(X_train,y_train)
prediction2=model2.predict(X_test)
cm2= confusion_matrix(y_test,prediction2)

# %%
cm2
# Out:
# array([[32,  8],
#        [11, 40]])

# %%
accuracy_score(y_test,prediction2)
# Out:
# 0.7912087912087912

# %%
print(classification_report(y_test, prediction2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77        40
#            1       0.83      0.78      0.81        51
#
#     accuracy                           0.79        91
#    macro avg       0.79      0.79      0.79        91
# weighted avg       0.79      0.79      0.79        91

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier()
model3 = rfc.fit(X_train, y_train)
prediction3 = model3.predict(X_test)
confusion_matrix(y_test, prediction3)
# Out:
# array([[35,  5],
#        [ 5, 46]])

# %%
accuracy_score(y_test, prediction3)
# Out:
# 0.8901098901098901

# %%
print(classification_report(y_test, prediction3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        40
#            1       0.90      0.90      0.90        51
#
#     accuracy                           0.89        91
#    macro avg       0.89      0.89      0.89        91
# weighted avg       0.89      0.89      0.89        91

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
from sklearn.svm import SVC

svm=SVC()
model4=svm.fit(X_train,y_train)
prediction4=model4.predict(X_test)
cm4= confusion_matrix(y_test,prediction4)

# %%
cm4
# Out:
# array([[33,  7],
#        [ 2, 49]])

# %%
accuracy_score(y_test, prediction4)
# Out:
# 0.9010989010989011

# %%
from sklearn.naive_bayes import GaussianNB

NB = GaussianNB()
model5 = NB.fit(X_train, y_train)
prediction5 = model5.predict(X_test)
cm5= confusion_matrix(y_test, prediction5)

# %%
cm5
# Out:
# array([[35,  5],
#        [ 6, 45]])

# %%
accuracy_score(y_test, prediction5)
# Out:
# 0.8791208791208791

# %%
print('cm4', cm4)
print('-----------')
print('cm5',cm5)
# Out:
# cm4 [[33  7]
#  [ 2 49]]
# -----------
# cm5 [[35  5]
#  [ 6 45]]

# %% [markdown]
# # KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN = KNeighborsClassifier()
model6 = KNN.fit(X_train, y_train)
prediction6 = model6.predict(X_test)
cm6= confusion_matrix(y_test, prediction5)
cm6
# Out:
# array([[35,  5],
#        [ 6, 45]])

# %%
accuracy_score(y_test, prediction6)
# Out:
# 0.8351648351648352

# %% [markdown]
# # showing multiple models score

# %%
print('KNN :', accuracy_score(y_test, prediction6))
print('lr :', accuracy_score(y_test, prediction1))
print('dtc :', accuracy_score(y_test, prediction2))
print('rfc :', accuracy_score(y_test, prediction3))
print('NB: ', accuracy_score(y_test, prediction4))
print('SVC :', accuracy_score(y_test, prediction5))
# Out:
# KNN : 0.8351648351648352
# lr : 0.9230769230769231
# dtc : 0.7912087912087912
# rfc : 0.8901098901098901
# NB:  0.9010989010989011
# SVC : 0.8791208791208791

# %% [markdown]
# # Best accuracy is given by Logistic Regression : 92

# %% [markdown]
# # followed by NB and Decision tree : 90

# %% [markdown]
# ### logistic Regression (LR): Achieved the highest accuracy score of 92.31%, indicating strong predictive performance on the dataset. LR may be a suitable choice for heart disease prediction due to its high accuracy and interpretability.

# %% [markdown]
# ### Naive Bayes (NB): Demonstrated competitive accuracy with a score of 90.11%. NB is known for its simplicity and efficiency in handling large datasets, making it a viable option for heart disease prediction.

# %% [markdown]
# ### Random Forest Classifier (RFC): Yielded an accuracy of 89.01%, showcasing robust performance. RFC's ability to handle non-linearity and feature importance analysis makes it a compelling choice for predictive modeling.

# %% [markdown]
# ### Support Vector Classifier (SVC): Achieved an accuracy score of 87.91%, indicating strong predictive capabilities. SVC's effectiveness in capturing complex relationships in data may render it suitable for heart disease prediction tasks.

# %% [markdown]
# ### K-Nearest Neighbors (KNN): Although yielding a slightly lower accuracy of 83.52%, KNN remains a viable option for heart disease prediction, especially considering its simplicity and ease of implementation.

# %% [markdown]
# ### Decision Tree Classifier (DTC): Exhibited a comparatively lower accuracy of 79.12%. While DTC may offer interpretability, its performance suggests it may not be the optimal choice for this particular task.
